# %%
import torch
import numpy as np

# %%
x = torch.tensor([1., 2. , 3.])

# %%
print(x + 4)
# Out:
# tensor([5., 6., 7.])

# %%
W = torch.tensor([0.123, -4.1, 2.4])

# %%
b = 0.7

# %%
z = x @ W

# %%
print(z)
# Out:
# tensor(-0.8770)
